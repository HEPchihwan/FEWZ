# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import os
import shutil
import re

# 현재 디렉토리의 파일 리스트
files = os.listdir('.')

# 섹터 및 관련 파일 처리용 정규표현식
pattern = re.compile(r'(NNLO.sect|entries|vegas_last_iter)(\d+)(\.pdf\.txt|\.txt)?$')

for f in files:
    match = pattern.match(f)
    if match:
        prefix, num_str, suffix = match.groups()
        num = int(num_str)
        folder_num = num - 1
        folder_name = f'sihyeon_DY_NNLO{folder_num}'

        if not os.path.isdir(folder_name):
            print(f'🚨 폴더 {folder_name} 없음 — 건너뜀')
            continue

        # 새 파일 이름 결정
        if prefix == 'NNLO.sect' and suffix == '.txt':
            new_name = f'NNLO.sect{num}.dat'
        elif prefix == 'NNLO.sect' and suffix == '.pdf.txt':
            new_name = f'NNLO.sect{num}.pdf.dat'
        else:
            new_name = f  # entries나 vegas_last_iter는 이름 유지

        # 이동
        shutil.move(f, os.path.join(folder_name, new_name))
        print(f'✅ {f} → {folder_name}/{new_name}')

print("\n모든 파일 정리 완료.")
# Out:
# ✅ entries54 → sihyeon_DY_NNLO53/entries54
# ✅ entries56 → sihyeon_DY_NNLO55/entries56
# ✅ entries55 → sihyeon_DY_NNLO54/entries55
# ✅ vegas_last_iter55 → sihyeon_DY_NNLO54/vegas_last_iter55
# ✅ vegas_last_iter17 → sihyeon_DY_NNLO16/vegas_last_iter17
# ✅ NNLO.sect1.txt → sihyeon_DY_NNLO0/NNLO.sect1.dat
# ✅ vegas_last_iter54 → sihyeon_DY_NNLO53/vegas_last_iter54
# ✅ NNLO.sect79.txt → sihyeon_DY_NNLO78/NNLO.sect79.dat
# ✅ vegas_last_iter18 → sihyeon_DY_NNLO17/vegas_last_iter18
# ✅ vegas_last_iter56 → sihyeon_DY_NNLO55/vegas_last_iter56
# ✅ vegas_last_iter125 → sihyeon_DY_NNLO124/vegas_last_iter125
# ✅ vegas_last_iter1 → sihyeon_DY_NNLO0/vegas_last_iter1
# ✅ entries1 → sihyeon_DY_NNLO0/entries1
# ✅ entries4 → sihyeon_DY_NNLO3/entries4
# ✅ entries5 → sihyeon_DY_NNLO4/entries5
# ✅ entries3 → sihyeon_DY_NNLO2/entries3
# ✅ entries7 → sihyeon_DY_NNLO6/entries7
# ✅ entries6 → sihyeon_DY_NNLO5/entries6
# ✅ entries2 → sihyeon_DY_NNLO1/entries2
# ✅ vegas_last_iter14 → sihyeon_DY_NNLO13/vegas_last_iter14
# ✅ NNLO.sect6.pdf.txt → sihyeon_DY_NNLO5/NNLO.sect6.pdf.dat
# ✅ NNLO.sect79.pdf.txt → sihyeon_DY_NNLO78/NNLO.sect79.pdf.dat
# ✅ entries9 → sihyeon_DY_NNLO8/entries9
# ✅ entries11 → sihyeon_DY_NNLO10/entries11
# ✅ entries12 → sihyeon_DY_NNLO11/entries12
# ✅ entries15 → sihyeon_DY_NNLO14/entries15
# ✅ entries10 → sihyeon_DY_NNLO9/entries10
# ✅ entries14 → sihyeon_DY_NNLO13/entries14
# ✅ entries8 → sihyeon_DY_NNLO7/entries8
# ✅ entries13 → sihyeon_DY_NNLO12/entries13
# ✅ vegas_last_iter4 → sihyeon_DY_NNLO3/vegas_last_iter4
# ✅ NNLO.sect6.txt → sihyeon_DY_NNLO5/NNLO.sect6.dat
# ✅ vegas_last_iter50 → sihyeon_DY_NNLO49/vegas_last_iter50
# ✅ NNLO.sect30.pdf.txt → sihyeon_DY_NNLO29/NNLO.sect30.pdf.dat
# ✅ vegas_last_iter6 → sihyeon_DY_NNLO5/vegas_last_iter6
# ✅ vegas_last_iter80 → sihyeon_DY_NNLO79/vegas_last_iter80
# ✅ vegas_last_iter5 → sihyeon_DY_NNLO4/vegas_last_iter5
# ✅ NNLO.sect80.txt → sihyeon_DY_NNLO79/NNLO.sect80.dat
# ✅ entries47 → sihyeon_DY_NNLO46/entries47
# ✅ entries44 → sihyeon_DY_NNLO43/entries44
# ✅ entries45 → sihyeon_DY_NNLO44/entries45
# ✅ entries50 → sihyeon_DY_NNLO49/entries50
# ✅ vegas_last_iter2 → sihyeon_DY_NNLO1/vegas_last_iter2
# ✅ vegas_last_iter78 → sihyeon_DY_NNLO77/vegas_last_iter78
# ✅ entries48 → sihyeon_DY_NNLO47/entries48
# ✅ vegas_last_iter3 → sihyeon_DY_NNLO2/vegas_last_iter3
# ✅ entries51 → sihyeon_DY_NNLO50/entries51
# ✅ NNLO.sect80.pdf.txt → sihyeon_DY_NNLO79/NNLO.sect80.pdf.dat
# ✅ entries49 → sihyeon_DY_NNLO48/entries49
# ✅ entries46 → sihyeon_DY_NNLO45/entries46
# ✅ entries42 → sihyeon_DY_NNLO41/entries42
# ✅ entries53 → sihyeon_DY_NNLO52/entries53
# ✅ entries52 → sihyeon_DY_NNLO51/entries52
# ✅ entries43 → sihyeon_DY_NNLO42/entries43
# ✅ vegas_last_iter7 → sihyeon_DY_NNLO6/vegas_last_iter7
# ✅ entries17 → sihyeon_DY_NNLO16/entries17
# ✅ entries20 → sihyeon_DY_NNLO19/entries20
# ✅ entries22 → sihyeon_DY_NNLO21/entries22
# ✅ entries21 → sihyeon_DY_NNLO20/entries21
# ✅ entries18 → sihyeon_DY_NNLO17/entries18
# ✅ vegas_last_iter11 → sihyeon_DY_NNLO10/vegas_last_iter11
# ✅ entries25 → sihyeon_DY_NNLO24/entries25
# ✅ vegas_last_iter15 → sihyeon_DY_NNLO14/vegas_last_iter15
# ✅ vegas_last_iter79 → sihyeon_DY_NNLO78/vegas_last_iter79
# ✅ vegas_last_iter52 → sihyeon_DY_NNLO51/vegas_last_iter52
# ✅ entries24 → sihyeon_DY_NNLO23/entries24
# ✅ entries27 → sihyeon_DY_NNLO26/entries27
# ✅ entries23 → sihyeon_DY_NNLO22/entries23
# ✅ entries26 → sihyeon_DY_NNLO25/entries26
# ✅ entries16 → sihyeon_DY_NNLO15/entries16
# ✅ entries19 → sihyeon_DY_NNLO18/entries19
# ✅ entries28 → sihyeon_DY_NNLO27/entries28
# ✅ NNLO.sect90.pdf.txt → sihyeon_DY_NNLO89/NNLO.sect90.pdf.dat
# ✅ vegas_last_iter88 → sihyeon_DY_NNLO87/vegas_last_iter88
# ✅ NNLO.sect1.pdf.txt → sihyeon_DY_NNLO0/NNLO.sect1.pdf.dat
# ✅ NNLO.sect72.txt → sihyeon_DY_NNLO71/NNLO.sect72.dat
# ✅ vegas_last_iter12 → sihyeon_DY_NNLO11/vegas_last_iter12
# ✅ NNLO.sect125.txt → sihyeon_DY_NNLO124/NNLO.sect125.dat
# ✅ vegas_last_iter10 → sihyeon_DY_NNLO9/vegas_last_iter10
# ✅ entries57 → sihyeon_DY_NNLO56/entries57
# ✅ entries65 → sihyeon_DY_NNLO64/entries65
# ✅ vegas_last_iter8 → sihyeon_DY_NNLO7/vegas_last_iter8
# ✅ entries76 → sihyeon_DY_NNLO75/entries76
# ✅ entries30 → sihyeon_DY_NNLO29/entries30
# ✅ entries61 → sihyeon_DY_NNLO60/entries61
# ✅ entries68 → sihyeon_DY_NNLO67/entries68
# ✅ entries62 → sihyeon_DY_NNLO61/entries62
# ✅ vegas_last_iter51 → sihyeon_DY_NNLO50/vegas_last_iter51
# ✅ entries36 → sihyeon_DY_NNLO35/entries36
# ✅ entries40 → sihyeon_DY_NNLO39/entries40
# ✅ entries29 → sihyeon_DY_NNLO28/entries29
# ✅ entries37 → sihyeon_DY_NNLO36/entries37
# ✅ entries32 → sihyeon_DY_NNLO31/entries32
# ✅ entries31 → sihyeon_DY_NNLO30/entries31
# ✅ entries39 → sihyeon_DY_NNLO38/entries39
# ✅ entries35 → sihyeon_DY_NNLO34/entries35
# ✅ entries34 → sihyeon_DY_NNLO33/entries34
# ✅ entries41 → sihyeon_DY_NNLO40/entries41
# ✅ entries38 → sihyeon_DY_NNLO37/entries38
# ✅ entries33 → sihyeon_DY_NNLO32/entries33
# ✅ vegas_last_iter48 → sihyeon_DY_NNLO47/vegas_last_iter48
# ✅ vegas_last_iter45 → sihyeon_DY_NNLO44/vegas_last_iter45
# ✅ NNLO.sect88.pdf.txt → sihyeon_DY_NNLO87/NNLO.sect88.pdf.dat
# ✅ NNLO.sect96.pdf.txt → sihyeon_DY_NNLO95/NNLO.sect96.pdf.dat
# ✅ entries60 → sihyeon_DY_NNLO59/entries60
# ✅ entries58 → sihyeon_DY_NNLO57/entries58
# ✅ entries63 → sihyeon_DY_NNLO62/entries63
# ✅ vegas_last_iter47 → sihyeon_DY_NNLO46/vegas_last_iter47
# ✅ NNLO.sect56.pdf.txt → sihyeon_DY_NNLO55/NNLO.sect56.pdf.dat
# ✅ entries67 → sihyeon_DY_NNLO66/entries67
# ✅ entries64 → sihyeon_DY_NNLO63/entries64
# ✅ entries59 → sihyeon_DY_NNLO58/entries59
# ✅ entries66 → sihyeon_DY_NNLO65/entries66
# ✅ NNLO.sect33.pdf.txt → sihyeon_DY_NNLO32/NNLO.sect33.pdf.dat
# ✅ vegas_last_iter53 → sihyeon_DY_NNLO52/vegas_last_iter53
# ✅ vegas_last_iter16 → sihyeon_DY_NNLO15/vegas_last_iter16
# ✅ vegas_last_iter20 → sihyeon_DY_NNLO19/vegas_last_iter20
# ✅ NNLO.sect92.txt → sihyeon_DY_NNLO91/NNLO.sect92.dat
# ✅ NNLO.sect61.txt → sihyeon_DY_NNLO60/NNLO.sect61.dat
# ✅ vegas_last_iter49 → sihyeon_DY_NNLO48/vegas_last_iter49
# ✅ NNLO.sect92.pdf.txt → sihyeon_DY_NNLO91/NNLO.sect92.pdf.dat
# ✅ vegas_last_iter85 → sihyeon_DY_NNLO84/vegas_last_iter85
# ✅ NNLO.sect52.pdf.txt → sihyeon_DY_NNLO51/NNLO.sect52.pdf.dat
# ✅ vegas_last_iter41 → sihyeon_DY_NNLO40/vegas_last_iter41
# ✅ vegas_last_iter19 → sihyeon_DY_NNLO18/vegas_last_iter19
# ✅ NNLO.sect53.txt → sihyeon_DY_NNLO52/NNLO.sect53.dat
# ✅ NNLO.sect15.txt → sihyeon_DY_NNLO14/NNLO.sect15.dat
# ✅ NNLO.sect85.txt → sihyeon_DY_NNLO84/NNLO.sect85.dat
# ✅ NNLO.sect24.txt → sihyeon_DY_NNLO23/NNLO.sect24.dat
# ✅ NNLO.sect7.pdf.txt → sihyeon_DY_NNLO6/NNLO.sect7.pdf.dat
# ✅ NNLO.sect27.pdf.txt → sihyeon_DY_NNLO26/NNLO.sect27.pdf.dat
# ✅ NNLO.sect53.pdf.txt → sihyeon_DY_NNLO52/NNLO.sect53.pdf.dat
# ✅ NNLO.sect15.pdf.txt → sihyeon_DY_NNLO14/NNLO.sect15.pdf.dat
# ✅ NNLO.sect101.pdf.txt → sihyeon_DY_NNLO100/NNLO.sect101.pdf.dat
# ✅ vegas_last_iter62 → sihyeon_DY_NNLO61/vegas_last_iter62
# ✅ NNLO.sect45.txt → sihyeon_DY_NNLO44/NNLO.sect45.dat
# ✅ vegas_last_iter82 → sihyeon_DY_NNLO81/vegas_last_iter82
# ✅ vegas_last_iter57 → sihyeon_DY_NNLO56/vegas_last_iter57
# ✅ NNLO.sect45.pdf.txt → sihyeon_DY_NNLO44/NNLO.sect45.pdf.dat
# ✅ NNLO.sect82.txt → sihyeon_DY_NNLO81/NNLO.sect82.dat
# ✅ vegas_last_iter9 → sihyeon_DY_NNLO8/vegas_last_iter9
# ✅ NNLO.sect82.pdf.txt → sihyeon_DY_NNLO81/NNLO.sect82.pdf.dat
# ✅ vegas_last_iter60 → sihyeon_DY_NNLO59/vegas_last_iter60
# ✅ NNLO.sect8.txt → sihyeon_DY_NNLO7/NNLO.sect8.dat
# ✅ NNLO.sect63.txt → sihyeon_DY_NNLO62/NNLO.sect63.dat
# ✅ NNLO.sect36.txt → sihyeon_DY_NNLO35/NNLO.sect36.dat
# ✅ vegas_last_iter44 → sihyeon_DY_NNLO43/vegas_last_iter44
# ✅ NNLO.sect63.pdf.txt → sihyeon_DY_NNLO62/NNLO.sect63.pdf.dat
# ✅ NNLO.sect58.txt → sihyeon_DY_NNLO57/NNLO.sect58.dat
# ✅ vegas_last_iter33 → sihyeon_DY_NNLO32/vegas_last_iter33
# ✅ NNLO.sect33.txt → sihyeon_DY_NNLO32/NNLO.sect33.dat
# ✅ NNLO.sect9.pdf.txt → sihyeon_DY_NNLO8/NNLO.sect9.pdf.dat
# ✅ vegas_last_iter63 → sihyeon_DY_NNLO62/vegas_last_iter63
# ✅ vegas_last_iter94 → sihyeon_DY_NNLO93/vegas_last_iter94
# ✅ NNLO.sect52.txt → sihyeon_DY_NNLO51/NNLO.sect52.dat
# ✅ vegas_last_iter31 → sihyeon_DY_NNLO30/vegas_last_iter31
# ✅ NNLO.sect31.txt → sihyeon_DY_NNLO30/NNLO.sect31.dat
# ✅ NNLO.sect31.pdf.txt → sihyeon_DY_NNLO30/NNLO.sect31.pdf.dat
# ✅ vegas_last_iter39 → sihyeon_DY_NNLO38/vegas_last_iter39
# ✅ NNLO.sect39.txt → sihyeon_DY_NNLO38/NNLO.sect39.dat
# ✅ NNLO.sect39.pdf.txt → sihyeon_DY_NNLO38/NNLO.sect39.pdf.dat
# ✅ vegas_last_iter34 → sihyeon_DY_NNLO33/vegas_last_iter34
# ✅ NNLO.sect94.txt → sihyeon_DY_NNLO93/NNLO.sect94.dat
# ✅ NNLO.sect13.txt → sihyeon_DY_NNLO12/NNLO.sect13.dat
# ✅ vegas_last_iter58 → sihyeon_DY_NNLO57/vegas_last_iter58
# ✅ NNLO.sect58.pdf.txt → sihyeon_DY_NNLO57/NNLO.sect58.pdf.dat
# ✅ vegas_last_iter89 → sihyeon_DY_NNLO88/vegas_last_iter89
# ✅ vegas_last_iter42 → sihyeon_DY_NNLO41/vegas_last_iter42
# ✅ NNLO.sect94.pdf.txt → sihyeon_DY_NNLO93/NNLO.sect94.pdf.dat
# ✅ NNLO.sect89.txt → sihyeon_DY_NNLO88/NNLO.sect89.dat
# ✅ vegas_last_iter32 → sihyeon_DY_NNLO31/vegas_last_iter32
# ✅ NNLO.sect93.txt → sihyeon_DY_NNLO92/NNLO.sect93.dat
# ✅ NNLO.sect37.txt → sihyeon_DY_NNLO36/NNLO.sect37.dat
# ✅ vegas_last_iter61 → sihyeon_DY_NNLO60/vegas_last_iter61
# ✅ NNLO.sect61.pdf.txt → sihyeon_DY_NNLO60/NNLO.sect61.pdf.dat
# ✅ NNLO.sect89.pdf.txt → sihyeon_DY_NNLO88/NNLO.sect89.pdf.dat
# ✅ vegas_last_iter68 → sihyeon_DY_NNLO67/vegas_last_iter68
# ✅ NNLO.sect93.pdf.txt → sihyeon_DY_NNLO92/NNLO.sect93.pdf.dat
# ✅ NNLO.sect38.txt → sihyeon_DY_NNLO37/NNLO.sect38.dat
# ✅ vegas_last_iter59 → sihyeon_DY_NNLO58/vegas_last_iter59
# ✅ NNLO.sect59.txt → sihyeon_DY_NNLO58/NNLO.sect59.dat
# ✅ NNLO.sect59.pdf.txt → sihyeon_DY_NNLO58/NNLO.sect59.pdf.dat
# ✅ vegas_last_iter65 → sihyeon_DY_NNLO64/vegas_last_iter65
# ✅ NNLO.sect65.pdf.txt → sihyeon_DY_NNLO64/NNLO.sect65.pdf.dat
# ✅ vegas_last_iter90 → sihyeon_DY_NNLO89/vegas_last_iter90
# ✅ vegas_last_iter28 → sihyeon_DY_NNLO27/vegas_last_iter28
# ✅ vegas_last_iter91 → sihyeon_DY_NNLO90/vegas_last_iter91
# ✅ vegas_last_iter83 → sihyeon_DY_NNLO82/vegas_last_iter83
# ✅ vegas_last_iter43 → sihyeon_DY_NNLO42/vegas_last_iter43
# ✅ vegas_last_iter66 → sihyeon_DY_NNLO65/vegas_last_iter66
# ✅ NNLO.sect43.txt → sihyeon_DY_NNLO42/NNLO.sect43.dat
# ✅ NNLO.sect43.pdf.txt → sihyeon_DY_NNLO42/NNLO.sect43.pdf.dat
# ✅ vegas_last_iter27 → sihyeon_DY_NNLO26/vegas_last_iter27
# ✅ vegas_last_iter46 → sihyeon_DY_NNLO45/vegas_last_iter46
# ✅ NNLO.sect8.pdf.txt → sihyeon_DY_NNLO7/NNLO.sect8.pdf.dat
# ✅ NNLO.sect46.txt → sihyeon_DY_NNLO45/NNLO.sect46.dat
# ✅ NNLO.sect57.txt → sihyeon_DY_NNLO56/NNLO.sect57.dat
# ✅ vegas_last_iter93 → sihyeon_DY_NNLO92/vegas_last_iter93
# ✅ NNLO.sect91.txt → sihyeon_DY_NNLO90/NNLO.sect91.dat
# ✅ NNLO.sect84.txt → sihyeon_DY_NNLO83/NNLO.sect84.dat
# ✅ vegas_last_iter35 → sihyeon_DY_NNLO34/vegas_last_iter35
# ✅ vegas_last_iter64 → sihyeon_DY_NNLO63/vegas_last_iter64
# ✅ NNLO.sect27.txt → sihyeon_DY_NNLO26/NNLO.sect27.dat
# ✅ vegas_last_iter92 → sihyeon_DY_NNLO91/vegas_last_iter92
# ✅ NNLO.sect91.pdf.txt → sihyeon_DY_NNLO90/NNLO.sect91.pdf.dat
# ✅ NNLO.sect83.txt → sihyeon_DY_NNLO82/NNLO.sect83.dat
# ✅ vegas_last_iter13 → sihyeon_DY_NNLO12/vegas_last_iter13
# ✅ NNLO.sect13.pdf.txt → sihyeon_DY_NNLO12/NNLO.sect13.pdf.dat
# ✅ NNLO.sect84.pdf.txt → sihyeon_DY_NNLO83/NNLO.sect84.pdf.dat
# ✅ vegas_last_iter36 → sihyeon_DY_NNLO35/vegas_last_iter36
# ✅ NNLO.sect36.pdf.txt → sihyeon_DY_NNLO35/NNLO.sect36.pdf.dat
# ✅ vegas_last_iter86 → sihyeon_DY_NNLO85/vegas_last_iter86
# ✅ vegas_last_iter24 → sihyeon_DY_NNLO23/vegas_last_iter24
# ✅ NNLO.sect24.pdf.txt → sihyeon_DY_NNLO23/NNLO.sect24.pdf.dat
# ✅ NNLO.sect86.txt → sihyeon_DY_NNLO85/NNLO.sect86.dat
# ✅ entries84 → sihyeon_DY_NNLO83/entries84
# ✅ entries105 → sihyeon_DY_NNLO104/entries105
# ✅ entries78 → sihyeon_DY_NNLO77/entries78
# ✅ vegas_last_iter37 → sihyeon_DY_NNLO36/vegas_last_iter37
# ✅ NNLO.sect37.pdf.txt → sihyeon_DY_NNLO36/NNLO.sect37.pdf.dat
# ✅ NNLO.sect86.pdf.txt → sihyeon_DY_NNLO85/NNLO.sect86.pdf.dat
# ✅ entries103 → sihyeon_DY_NNLO102/entries103
# ✅ vegas_last_iter38 → sihyeon_DY_NNLO37/vegas_last_iter38
# ✅ NNLO.sect67.pdf.txt → sihyeon_DY_NNLO66/NNLO.sect67.pdf.dat
# ✅ NNLO.sect65.txt → sihyeon_DY_NNLO64/NNLO.sect65.dat
# ✅ entries127 → sihyeon_DY_NNLO126/entries127
# ✅ entries77 → sihyeon_DY_NNLO76/entries77
# ✅ entries98 → sihyeon_DY_NNLO97/entries98
# ✅ entries104 → sihyeon_DY_NNLO103/entries104
# ✅ entries70 → sihyeon_DY_NNLO69/entries70
# ✅ entries113 → sihyeon_DY_NNLO112/entries113
# ✅ entries82 → sihyeon_DY_NNLO81/entries82
# ✅ entries117 → sihyeon_DY_NNLO116/entries117
# ✅ entries106 → sihyeon_DY_NNLO105/entries106
# ✅ entries118 → sihyeon_DY_NNLO117/entries118
# ✅ entries72 → sihyeon_DY_NNLO71/entries72
# ✅ entries107 → sihyeon_DY_NNLO106/entries107
# ✅ entries100 → sihyeon_DY_NNLO99/entries100
# ✅ entries119 → sihyeon_DY_NNLO118/entries119
# ✅ entries81 → sihyeon_DY_NNLO80/entries81
# ✅ entries90 → sihyeon_DY_NNLO89/entries90
# ✅ entries95 → sihyeon_DY_NNLO94/entries95
# ✅ entries74 → sihyeon_DY_NNLO73/entries74
# ✅ entries123 → sihyeon_DY_NNLO122/entries123
# ✅ entries111 → sihyeon_DY_NNLO110/entries111
# ✅ entries83 → sihyeon_DY_NNLO82/entries83
# ✅ entries126 → sihyeon_DY_NNLO125/entries126
# ✅ entries79 → sihyeon_DY_NNLO78/entries79
# ✅ entries73 → sihyeon_DY_NNLO72/entries73
# ✅ NNLO.sect115.txt → sihyeon_DY_NNLO114/NNLO.sect115.dat
# ✅ NNLO.sect110.pdf.txt → sihyeon_DY_NNLO109/NNLO.sect110.pdf.dat
# ✅ NNLO.sect74.pdf.txt → sihyeon_DY_NNLO73/NNLO.sect74.pdf.dat
# ✅ vegas_last_iter107 → sihyeon_DY_NNLO106/vegas_last_iter107
# ✅ entries89 → sihyeon_DY_NNLO88/entries89
# ✅ entries91 → sihyeon_DY_NNLO90/entries91
# ✅ entries124 → sihyeon_DY_NNLO123/entries124
# ✅ NNLO.sect75.txt → sihyeon_DY_NNLO74/NNLO.sect75.dat
# ✅ NNLO.sect127.txt → sihyeon_DY_NNLO126/NNLO.sect127.dat
# ✅ entries71 → sihyeon_DY_NNLO70/entries71
# ✅ entries75 → sihyeon_DY_NNLO74/entries75
# ✅ NNLO.sect115.pdf.txt → sihyeon_DY_NNLO114/NNLO.sect115.pdf.dat
# ✅ NNLO.sect71.txt → sihyeon_DY_NNLO70/NNLO.sect71.dat
# ✅ NNLO.sect2.txt → sihyeon_DY_NNLO1/NNLO.sect2.dat
# ✅ vegas_last_iter127 → sihyeon_DY_NNLO126/vegas_last_iter127
# ✅ entries93 → sihyeon_DY_NNLO92/entries93
# ✅ entries101 → sihyeon_DY_NNLO100/entries101
# ✅ entries85 → sihyeon_DY_NNLO84/entries85
# ✅ NNLO.sect117.pdf.txt → sihyeon_DY_NNLO116/NNLO.sect117.pdf.dat
# ✅ entries120 → sihyeon_DY_NNLO119/entries120
# ✅ entries125 → sihyeon_DY_NNLO124/entries125
# ✅ entries114 → sihyeon_DY_NNLO113/entries114
# ✅ entries109 → sihyeon_DY_NNLO108/entries109
# ✅ vegas_last_iter110 → sihyeon_DY_NNLO109/vegas_last_iter110
# ✅ NNLO.sect69.pdf.txt → sihyeon_DY_NNLO68/NNLO.sect69.pdf.dat
# ✅ NNLO.sect75.pdf.txt → sihyeon_DY_NNLO74/NNLO.sect75.pdf.dat
# ✅ NNLO.sect127.pdf.txt → sihyeon_DY_NNLO126/NNLO.sect127.pdf.dat
# ✅ entries116 → sihyeon_DY_NNLO115/entries116
# ✅ vegas_last_iter70 → sihyeon_DY_NNLO69/vegas_last_iter70
# ✅ entries99 → sihyeon_DY_NNLO98/entries99
# ✅ NNLO.sect95.txt → sihyeon_DY_NNLO94/NNLO.sect95.dat
# ✅ entries112 → sihyeon_DY_NNLO111/entries112
# ✅ entries108 → sihyeon_DY_NNLO107/entries108
# ✅ NNLO.sect121.txt → sihyeon_DY_NNLO120/NNLO.sect121.dat
# ✅ NNLO.sect70.pdf.txt → sihyeon_DY_NNLO69/NNLO.sect70.pdf.dat
# ✅ entries102 → sihyeon_DY_NNLO101/entries102
# ✅ NNLO.sect69.txt → sihyeon_DY_NNLO68/NNLO.sect69.dat
# ✅ NNLO.sect2.pdf.txt → sihyeon_DY_NNLO1/NNLO.sect2.pdf.dat
# ✅ NNLO.sect107.txt → sihyeon_DY_NNLO106/NNLO.sect107.dat
# ✅ entries97 → sihyeon_DY_NNLO96/entries97
# ✅ entries110 → sihyeon_DY_NNLO109/entries110
# ✅ entries121 → sihyeon_DY_NNLO120/entries121
# ✅ vegas_last_iter71 → sihyeon_DY_NNLO70/vegas_last_iter71
# ✅ vegas_last_iter74 → sihyeon_DY_NNLO73/vegas_last_iter74
# ✅ vegas_last_iter121 → sihyeon_DY_NNLO120/vegas_last_iter121
# ✅ vegas_last_iter109 → sihyeon_DY_NNLO108/vegas_last_iter109
# ✅ entries96 → sihyeon_DY_NNLO95/entries96
# ✅ NNLO.sect117.txt → sihyeon_DY_NNLO116/NNLO.sect117.dat
# ✅ entries115 → sihyeon_DY_NNLO114/entries115
# ✅ entries92 → sihyeon_DY_NNLO91/entries92
# ✅ entries122 → sihyeon_DY_NNLO121/entries122
# ✅ entries88 → sihyeon_DY_NNLO87/entries88
# ✅ vegas_last_iter69 → sihyeon_DY_NNLO68/vegas_last_iter69
# ✅ NNLO.sect71.pdf.txt → sihyeon_DY_NNLO70/NNLO.sect71.pdf.dat
# ✅ vegas_last_iter75 → sihyeon_DY_NNLO74/vegas_last_iter75
# ✅ NNLO.sect107.pdf.txt → sihyeon_DY_NNLO106/NNLO.sect107.pdf.dat
# ✅ entries87 → sihyeon_DY_NNLO86/entries87
# ✅ entries80 → sihyeon_DY_NNLO79/entries80
# ✅ entries94 → sihyeon_DY_NNLO93/entries94
# ✅ entries86 → sihyeon_DY_NNLO85/entries86
# ✅ entries69 → sihyeon_DY_NNLO68/entries69
# ✅ vegas_last_iter30 → sihyeon_DY_NNLO29/vegas_last_iter30
# ✅ NNLO.sect30.txt → sihyeon_DY_NNLO29/NNLO.sect30.dat
# ✅ NNLO.sect90.txt → sihyeon_DY_NNLO89/NNLO.sect90.dat
# ✅ vegas_last_iter67 → sihyeon_DY_NNLO66/vegas_last_iter67
# ✅ NNLO.sect67.txt → sihyeon_DY_NNLO66/NNLO.sect67.dat
# ✅ NNLO.sect38.pdf.txt → sihyeon_DY_NNLO37/NNLO.sect38.pdf.dat
# ✅ vegas_last_iter21 → sihyeon_DY_NNLO20/vegas_last_iter21
# ✅ NNLO.sect21.txt → sihyeon_DY_NNLO20/NNLO.sect21.dat
# ✅ NNLO.sect21.pdf.txt → sihyeon_DY_NNLO20/NNLO.sect21.pdf.dat
# ✅ vegas_last_iter26 → sihyeon_DY_NNLO25/vegas_last_iter26
# ✅ NNLO.sect26.txt → sihyeon_DY_NNLO25/NNLO.sect26.dat
# ✅ NNLO.sect26.pdf.txt → sihyeon_DY_NNLO25/NNLO.sect26.pdf.dat
# ✅ vegas_last_iter29 → sihyeon_DY_NNLO28/vegas_last_iter29
# ✅ NNLO.sect29.txt → sihyeon_DY_NNLO28/NNLO.sect29.dat
# ✅ NNLO.sect29.pdf.txt → sihyeon_DY_NNLO28/NNLO.sect29.pdf.dat
# ✅ vegas_last_iter23 → sihyeon_DY_NNLO22/vegas_last_iter23
# ✅ NNLO.sect23.txt → sihyeon_DY_NNLO22/NNLO.sect23.dat
# ✅ NNLO.sect23.pdf.txt → sihyeon_DY_NNLO22/NNLO.sect23.pdf.dat
# ✅ vegas_last_iter22 → sihyeon_DY_NNLO21/vegas_last_iter22
# ✅ NNLO.sect22.txt → sihyeon_DY_NNLO21/NNLO.sect22.dat
# ✅ NNLO.sect22.pdf.txt → sihyeon_DY_NNLO21/NNLO.sect22.pdf.dat
# ✅ vegas_last_iter25 → sihyeon_DY_NNLO24/vegas_last_iter25
# ✅ NNLO.sect25.txt → sihyeon_DY_NNLO24/NNLO.sect25.dat
# ✅ NNLO.sect25.pdf.txt → sihyeon_DY_NNLO24/NNLO.sect25.pdf.dat
# ✅ vegas_last_iter76 → sihyeon_DY_NNLO75/vegas_last_iter76
# ✅ NNLO.sect100.txt → sihyeon_DY_NNLO99/NNLO.sect100.dat
# ✅ NNLO.sect96.txt → sihyeon_DY_NNLO95/NNLO.sect96.dat
# ✅ vegas_last_iter105 → sihyeon_DY_NNLO104/vegas_last_iter105
# ✅ NNLO.sect100.pdf.txt → sihyeon_DY_NNLO99/NNLO.sect100.pdf.dat
# ✅ NNLO.sect125.pdf.txt → sihyeon_DY_NNLO124/NNLO.sect125.pdf.dat
# ✅ vegas_last_iter112 → sihyeon_DY_NNLO111/vegas_last_iter112
# ✅ NNLO.sect99.txt → sihyeon_DY_NNLO98/NNLO.sect99.dat
# ✅ NNLO.sect102.txt → sihyeon_DY_NNLO101/NNLO.sect102.dat
# ✅ vegas_last_iter118 → sihyeon_DY_NNLO117/vegas_last_iter118
# ✅ NNLO.sect35.txt → sihyeon_DY_NNLO34/NNLO.sect35.dat
# ✅ NNLO.sect87.pdf.txt → sihyeon_DY_NNLO86/NNLO.sect87.pdf.dat
# ✅ vegas_last_iter113 → sihyeon_DY_NNLO112/vegas_last_iter113
# ✅ NNLO.sect99.pdf.txt → sihyeon_DY_NNLO98/NNLO.sect99.pdf.dat
# ✅ NNLO.sect116.txt → sihyeon_DY_NNLO115/NNLO.sect116.dat
# ✅ vegas_last_iter111 → sihyeon_DY_NNLO110/vegas_last_iter111
# ✅ NNLO.sect35.pdf.txt → sihyeon_DY_NNLO34/NNLO.sect35.pdf.dat
# ✅ NNLO.sect49.txt → sihyeon_DY_NNLO48/NNLO.sect49.dat
# ✅ vegas_last_iter99 → sihyeon_DY_NNLO98/vegas_last_iter99
# ✅ vegas_last_iter96 → sihyeon_DY_NNLO95/vegas_last_iter96
# ✅ NNLO.sect49.pdf.txt → sihyeon_DY_NNLO48/NNLO.sect49.pdf.dat
# ✅ vegas_last_iter108 → sihyeon_DY_NNLO107/vegas_last_iter108
# ✅ vegas_last_iter103 → sihyeon_DY_NNLO102/vegas_last_iter103
# ✅ NNLO.sect111.txt → sihyeon_DY_NNLO110/NNLO.sect111.dat
# ✅ NNLO.sect111.pdf.txt → sihyeon_DY_NNLO110/NNLO.sect111.pdf.dat
# ✅ NNLO.sect103.txt → sihyeon_DY_NNLO102/NNLO.sect103.dat
# ✅ NNLO.sect103.pdf.txt → sihyeon_DY_NNLO102/NNLO.sect103.pdf.dat
# ✅ vegas_last_iter102 → sihyeon_DY_NNLO101/vegas_last_iter102
# ✅ vegas_last_iter119 → sihyeon_DY_NNLO118/vegas_last_iter119
# ✅ NNLO.sect10.txt → sihyeon_DY_NNLO9/NNLO.sect10.dat
# ✅ NNLO.sect119.txt → sihyeon_DY_NNLO118/NNLO.sect119.dat
# ✅ NNLO.sect119.pdf.txt → sihyeon_DY_NNLO118/NNLO.sect119.pdf.dat
# ✅ NNLO.sect7.txt → sihyeon_DY_NNLO6/NNLO.sect7.dat
# ✅ vegas_last_iter116 → sihyeon_DY_NNLO115/vegas_last_iter116
# ✅ NNLO.sect116.pdf.txt → sihyeon_DY_NNLO115/NNLO.sect116.pdf.dat
# ✅ NNLO.sect10.pdf.txt → sihyeon_DY_NNLO9/NNLO.sect10.pdf.dat
# ✅ vegas_last_iter106 → sihyeon_DY_NNLO105/vegas_last_iter106
# ✅ NNLO.sect123.txt → sihyeon_DY_NNLO122/NNLO.sect123.dat
# ✅ NNLO.sect106.pdf.txt → sihyeon_DY_NNLO105/NNLO.sect106.pdf.dat
# ✅ vegas_last_iter114 → sihyeon_DY_NNLO113/vegas_last_iter114
# ✅ NNLO.sect51.txt → sihyeon_DY_NNLO50/NNLO.sect51.dat
# ✅ NNLO.sect114.pdf.txt → sihyeon_DY_NNLO113/NNLO.sect114.pdf.dat
# ✅ vegas_last_iter115 → sihyeon_DY_NNLO114/vegas_last_iter115
# ✅ NNLO.sect54.pdf.txt → sihyeon_DY_NNLO53/NNLO.sect54.pdf.dat
# ✅ NNLO.sect74.txt → sihyeon_DY_NNLO73/NNLO.sect74.dat
# ✅ NNLO.sect121.pdf.txt → sihyeon_DY_NNLO120/NNLO.sect121.pdf.dat
# ✅ vegas_last_iter120 → sihyeon_DY_NNLO119/vegas_last_iter120
# ✅ NNLO.sect78.txt → sihyeon_DY_NNLO77/NNLO.sect78.dat
# ✅ NNLO.sect83.pdf.txt → sihyeon_DY_NNLO82/NNLO.sect83.pdf.dat
# ✅ NNLO.sect78.pdf.txt → sihyeon_DY_NNLO77/NNLO.sect78.pdf.dat
# ✅ NNLO.sect47.txt → sihyeon_DY_NNLO46/NNLO.sect47.dat
# ✅ NNLO.sect47.pdf.txt → sihyeon_DY_NNLO46/NNLO.sect47.pdf.dat
# ✅ NNLO.sect34.txt → sihyeon_DY_NNLO33/NNLO.sect34.dat
# ✅ NNLO.sect34.pdf.txt → sihyeon_DY_NNLO33/NNLO.sect34.pdf.dat
# ✅ vegas_last_iter126 → sihyeon_DY_NNLO125/vegas_last_iter126
# ✅ vegas_last_iter117 → sihyeon_DY_NNLO116/vegas_last_iter117
# ✅ NNLO.sect126.txt → sihyeon_DY_NNLO125/NNLO.sect126.dat
# ✅ NNLO.sect126.pdf.txt → sihyeon_DY_NNLO125/NNLO.sect126.pdf.dat
# ✅ NNLO.sect55.txt → sihyeon_DY_NNLO54/NNLO.sect55.dat
# ✅ NNLO.sect109.txt → sihyeon_DY_NNLO108/NNLO.sect109.dat
# ✅ NNLO.sect55.pdf.txt → sihyeon_DY_NNLO54/NNLO.sect55.pdf.dat
# ✅ NNLO.sect109.pdf.txt → sihyeon_DY_NNLO108/NNLO.sect109.pdf.dat
# ✅ NNLO.sect12.txt → sihyeon_DY_NNLO11/NNLO.sect12.dat
# ✅ NNLO.sect12.pdf.txt → sihyeon_DY_NNLO11/NNLO.sect12.pdf.dat
# ✅ NNLO.sect5.txt → sihyeon_DY_NNLO4/NNLO.sect5.dat
# ✅ NNLO.sect5.pdf.txt → sihyeon_DY_NNLO4/NNLO.sect5.pdf.dat
# ✅ NNLO.sect68.txt → sihyeon_DY_NNLO67/NNLO.sect68.dat
# ✅ NNLO.sect68.pdf.txt → sihyeon_DY_NNLO67/NNLO.sect68.pdf.dat
# ✅ NNLO.sect44.txt → sihyeon_DY_NNLO43/NNLO.sect44.dat
# ✅ NNLO.sect44.pdf.txt → sihyeon_DY_NNLO43/NNLO.sect44.pdf.dat
# ✅ vegas_last_iter72 → sihyeon_DY_NNLO71/vegas_last_iter72
# ✅ NNLO.sect88.txt → sihyeon_DY_NNLO87/NNLO.sect88.dat
# ✅ NNLO.sect72.pdf.txt → sihyeon_DY_NNLO71/NNLO.sect72.pdf.dat
# ✅ NNLO.sect46.pdf.txt → sihyeon_DY_NNLO45/NNLO.sect46.pdf.dat
# ✅ NNLO.sect57.pdf.txt → sihyeon_DY_NNLO56/NNLO.sect57.pdf.dat
# ✅ NNLO.sect62.txt → sihyeon_DY_NNLO61/NNLO.sect62.dat
# ✅ NNLO.sect62.pdf.txt → sihyeon_DY_NNLO61/NNLO.sect62.pdf.dat
# ✅ vegas_last_iter104 → sihyeon_DY_NNLO103/vegas_last_iter104
# ✅ vegas_last_iter124 → sihyeon_DY_NNLO123/vegas_last_iter124
# ✅ vegas_last_iter77 → sihyeon_DY_NNLO76/vegas_last_iter77
# ✅ NNLO.sect42.txt → sihyeon_DY_NNLO41/NNLO.sect42.dat
# ✅ NNLO.sect104.txt → sihyeon_DY_NNLO103/NNLO.sect104.dat
# ✅ NNLO.sect42.pdf.txt → sihyeon_DY_NNLO41/NNLO.sect42.pdf.dat
# ✅ NNLO.sect3.txt → sihyeon_DY_NNLO2/NNLO.sect3.dat
# ✅ NNLO.sect3.pdf.txt → sihyeon_DY_NNLO2/NNLO.sect3.pdf.dat
# ✅ NNLO.sect104.pdf.txt → sihyeon_DY_NNLO103/NNLO.sect104.pdf.dat
# ✅ NNLO.sect124.txt → sihyeon_DY_NNLO123/NNLO.sect124.dat
# ✅ NNLO.sect77.txt → sihyeon_DY_NNLO76/NNLO.sect77.dat
# ✅ NNLO.sect32.txt → sihyeon_DY_NNLO31/NNLO.sect32.dat
# ✅ NNLO.sect124.pdf.txt → sihyeon_DY_NNLO123/NNLO.sect124.pdf.dat
# ✅ NNLO.sect77.pdf.txt → sihyeon_DY_NNLO76/NNLO.sect77.pdf.dat
# ✅ NNLO.sect32.pdf.txt → sihyeon_DY_NNLO31/NNLO.sect32.pdf.dat
# ✅ NNLO.sect9.txt → sihyeon_DY_NNLO8/NNLO.sect9.dat
# ✅ NNLO.sect56.txt → sihyeon_DY_NNLO55/NNLO.sect56.dat
# ✅ NNLO.sect17.txt → sihyeon_DY_NNLO16/NNLO.sect17.dat
# ✅ NNLO.sect17.pdf.txt → sihyeon_DY_NNLO16/NNLO.sect17.pdf.dat
# ✅ NNLO.sect76.txt → sihyeon_DY_NNLO75/NNLO.sect76.dat
# ✅ NNLO.sect76.pdf.txt → sihyeon_DY_NNLO75/NNLO.sect76.pdf.dat
# ✅ vegas_last_iter98 → sihyeon_DY_NNLO97/vegas_last_iter98
# ✅ NNLO.sect64.txt → sihyeon_DY_NNLO63/NNLO.sect64.dat
# ✅ NNLO.sect98.txt → sihyeon_DY_NNLO97/NNLO.sect98.dat
# ✅ NNLO.sect64.pdf.txt → sihyeon_DY_NNLO63/NNLO.sect64.pdf.dat
# ✅ NNLO.sect98.pdf.txt → sihyeon_DY_NNLO97/NNLO.sect98.pdf.dat
# ✅ vegas_last_iter101 → sihyeon_DY_NNLO100/vegas_last_iter101
# ✅ NNLO.sect101.txt → sihyeon_DY_NNLO100/NNLO.sect101.dat
# ✅ NNLO.sect85.pdf.txt → sihyeon_DY_NNLO84/NNLO.sect85.pdf.dat
# ✅ NNLO.sect66.txt → sihyeon_DY_NNLO65/NNLO.sect66.dat
# ✅ NNLO.sect66.pdf.txt → sihyeon_DY_NNLO65/NNLO.sect66.pdf.dat
# ✅ vegas_last_iter73 → sihyeon_DY_NNLO72/vegas_last_iter73
# ✅ NNLO.sect73.txt → sihyeon_DY_NNLO72/NNLO.sect73.dat
# ✅ NNLO.sect73.pdf.txt → sihyeon_DY_NNLO72/NNLO.sect73.pdf.dat
# ✅ NNLO.sect54.txt → sihyeon_DY_NNLO53/NNLO.sect54.dat
# ✅ NNLO.sect110.txt → sihyeon_DY_NNLO109/NNLO.sect110.dat
# ✅ NNLO.sect48.txt → sihyeon_DY_NNLO47/NNLO.sect48.dat
# ✅ NNLO.sect48.pdf.txt → sihyeon_DY_NNLO47/NNLO.sect48.pdf.dat
# ✅ NNLO.sect18.txt → sihyeon_DY_NNLO17/NNLO.sect18.dat
# ✅ NNLO.sect18.pdf.txt → sihyeon_DY_NNLO17/NNLO.sect18.pdf.dat
# ✅ NNLO.sect11.txt → sihyeon_DY_NNLO10/NNLO.sect11.dat
# ✅ NNLO.sect11.pdf.txt → sihyeon_DY_NNLO10/NNLO.sect11.pdf.dat
# ✅ vegas_last_iter123 → sihyeon_DY_NNLO122/vegas_last_iter123
# ✅ NNLO.sect106.txt → sihyeon_DY_NNLO105/NNLO.sect106.dat
# ✅ NNLO.sect123.pdf.txt → sihyeon_DY_NNLO122/NNLO.sect123.pdf.dat
# ✅ NNLO.sect114.txt → sihyeon_DY_NNLO113/NNLO.sect114.dat
# ✅ NNLO.sect51.pdf.txt → sihyeon_DY_NNLO50/NNLO.sect51.pdf.dat
# ✅ NNLO.sect50.txt → sihyeon_DY_NNLO49/NNLO.sect50.dat
# ✅ NNLO.sect50.pdf.txt → sihyeon_DY_NNLO49/NNLO.sect50.pdf.dat
# ✅ NNLO.sect60.txt → sihyeon_DY_NNLO59/NNLO.sect60.dat
# ✅ NNLO.sect60.pdf.txt → sihyeon_DY_NNLO59/NNLO.sect60.pdf.dat
# ✅ vegas_last_iter87 → sihyeon_DY_NNLO86/vegas_last_iter87
# ✅ NNLO.sect87.txt → sihyeon_DY_NNLO86/NNLO.sect87.dat
# ✅ NNLO.sect102.pdf.txt → sihyeon_DY_NNLO101/NNLO.sect102.pdf.dat
# ✅ vegas_last_iter95 → sihyeon_DY_NNLO94/vegas_last_iter95
# ✅ NNLO.sect70.txt → sihyeon_DY_NNLO69/NNLO.sect70.dat
# ✅ NNLO.sect95.pdf.txt → sihyeon_DY_NNLO94/NNLO.sect95.pdf.dat
# ✅ NNLO.sect41.txt → sihyeon_DY_NNLO40/NNLO.sect41.dat
# ✅ NNLO.sect41.pdf.txt → sihyeon_DY_NNLO40/NNLO.sect41.pdf.dat
# ✅ NNLO.sect14.txt → sihyeon_DY_NNLO13/NNLO.sect14.dat
# ✅ NNLO.sect14.pdf.txt → sihyeon_DY_NNLO13/NNLO.sect14.pdf.dat
# ✅ NNLO.sect28.txt → sihyeon_DY_NNLO27/NNLO.sect28.dat
# ✅ NNLO.sect28.pdf.txt → sihyeon_DY_NNLO27/NNLO.sect28.pdf.dat
# ✅ NNLO.sect16.txt → sihyeon_DY_NNLO15/NNLO.sect16.dat
# ✅ NNLO.sect16.pdf.txt → sihyeon_DY_NNLO15/NNLO.sect16.pdf.dat
# ✅ vegas_last_iter81 → sihyeon_DY_NNLO80/vegas_last_iter81
# ✅ NNLO.sect81.txt → sihyeon_DY_NNLO80/NNLO.sect81.dat
# ✅ NNLO.sect81.pdf.txt → sihyeon_DY_NNLO80/NNLO.sect81.pdf.dat
# ✅ vegas_last_iter40 → sihyeon_DY_NNLO39/vegas_last_iter40
# ✅ NNLO.sect4.txt → sihyeon_DY_NNLO3/NNLO.sect4.dat
# ✅ NNLO.sect4.pdf.txt → sihyeon_DY_NNLO3/NNLO.sect4.pdf.dat
# ✅ NNLO.sect40.txt → sihyeon_DY_NNLO39/NNLO.sect40.dat
# ✅ NNLO.sect40.pdf.txt → sihyeon_DY_NNLO39/NNLO.sect40.pdf.dat
# ✅ NNLO.sect112.txt → sihyeon_DY_NNLO111/NNLO.sect112.dat
# ✅ NNLO.sect112.pdf.txt → sihyeon_DY_NNLO111/NNLO.sect112.pdf.dat
# ✅ NNLO.sect113.txt → sihyeon_DY_NNLO112/NNLO.sect113.dat
# ✅ NNLO.sect113.pdf.txt → sihyeon_DY_NNLO112/NNLO.sect113.pdf.dat
# ✅ vegas_last_iter97 → sihyeon_DY_NNLO96/vegas_last_iter97
# ✅ NNLO.sect97.txt → sihyeon_DY_NNLO96/NNLO.sect97.dat
# ✅ NNLO.sect97.pdf.txt → sihyeon_DY_NNLO96/NNLO.sect97.pdf.dat
# ✅ vegas_last_iter122 → sihyeon_DY_NNLO121/vegas_last_iter122
# ✅ NNLO.sect122.txt → sihyeon_DY_NNLO121/NNLO.sect122.dat
# ✅ NNLO.sect122.pdf.txt → sihyeon_DY_NNLO121/NNLO.sect122.pdf.dat
# ✅ vegas_last_iter84 → sihyeon_DY_NNLO83/vegas_last_iter84
# ✅ NNLO.sect120.txt → sihyeon_DY_NNLO119/NNLO.sect120.dat
# ✅ NNLO.sect105.txt → sihyeon_DY_NNLO104/NNLO.sect105.dat
# ✅ NNLO.sect120.pdf.txt → sihyeon_DY_NNLO119/NNLO.sect120.pdf.dat
# ✅ NNLO.sect105.pdf.txt → sihyeon_DY_NNLO104/NNLO.sect105.pdf.dat
# ✅ NNLO.sect108.txt → sihyeon_DY_NNLO107/NNLO.sect108.dat
# ✅ NNLO.sect108.pdf.txt → sihyeon_DY_NNLO107/NNLO.sect108.pdf.dat
# ✅ NNLO.sect19.txt → sihyeon_DY_NNLO18/NNLO.sect19.dat
# ✅ NNLO.sect19.pdf.txt → sihyeon_DY_NNLO18/NNLO.sect19.pdf.dat
# ✅ NNLO.sect20.txt → sihyeon_DY_NNLO19/NNLO.sect20.dat
# ✅ NNLO.sect20.pdf.txt → sihyeon_DY_NNLO19/NNLO.sect20.pdf.dat
# ✅ NNLO.sect118.txt → sihyeon_DY_NNLO117/NNLO.sect118.dat
# ✅ NNLO.sect118.pdf.txt → sihyeon_DY_NNLO117/NNLO.sect118.pdf.dat
# ✅ vegas_last_iter100 → sihyeon_DY_NNLO99/vegas_last_iter100
#
# 모든 파일 정리 완료.

# %%
# -*- coding: utf-8 -*-
import os
import re

# 폴더들을 순회
for folder in os.listdir('.'):
    if folder.startswith('sihyeon_DY_NNLO') and os.path.isdir(folder):
        folder_num = int(folder.replace('sihyeon_DY_NNLO', ''))
        sect_num = folder_num + 1

        files = os.listdir(folder)

        for f in files:
            old_path = os.path.join(folder, f)

            # 이름 변경 조건
            if f == 'NNLO.sect%d.dat' % sect_num:
                new_name = 'NNLO.sect%d.final.dat' % sect_num
            elif f == 'NNLO.sect%d.pdf.dat' % sect_num:
                new_name = 'NNLO.sect%d.pdf.final.dat' % sect_num
            
            else:
                continue  # 해당되지 않으면 건너뜀

            new_path = os.path.join(folder, new_name)
            os.rename(old_path, new_path)
            print('✅ Renamed: %s → %s' % (f, new_name))

print('\n🎉 모든 이름 변경 완료.')
# Out:
# ✅ Renamed: NNLO.sect1.dat → NNLO.sect1.final.dat
# ✅ Renamed: NNLO.sect1.pdf.dat → NNLO.sect1.pdf.final.dat
# ✅ Renamed: NNLO.sect2.dat → NNLO.sect2.final.dat
# ✅ Renamed: NNLO.sect2.pdf.dat → NNLO.sect2.pdf.final.dat
# ✅ Renamed: NNLO.sect3.dat → NNLO.sect3.final.dat
# ✅ Renamed: NNLO.sect3.pdf.dat → NNLO.sect3.pdf.final.dat
# ✅ Renamed: NNLO.sect4.dat → NNLO.sect4.final.dat
# ✅ Renamed: NNLO.sect4.pdf.dat → NNLO.sect4.pdf.final.dat
# ✅ Renamed: NNLO.sect5.dat → NNLO.sect5.final.dat
# ✅ Renamed: NNLO.sect5.pdf.dat → NNLO.sect5.pdf.final.dat
# ✅ Renamed: NNLO.sect6.pdf.dat → NNLO.sect6.pdf.final.dat
# ✅ Renamed: NNLO.sect6.dat → NNLO.sect6.final.dat
# ✅ Renamed: NNLO.sect7.pdf.dat → NNLO.sect7.pdf.final.dat
# ✅ Renamed: NNLO.sect7.dat → NNLO.sect7.final.dat
# ✅ Renamed: NNLO.sect8.dat → NNLO.sect8.final.dat
# ✅ Renamed: NNLO.sect8.pdf.dat → NNLO.sect8.pdf.final.dat
# ✅ Renamed: NNLO.sect9.pdf.dat → NNLO.sect9.pdf.final.dat
# ✅ Renamed: NNLO.sect9.dat → NNLO.sect9.final.dat
# ✅ Renamed: NNLO.sect10.dat → NNLO.sect10.final.dat
# ✅ Renamed: NNLO.sect10.pdf.dat → NNLO.sect10.pdf.final.dat
# ✅ Renamed: NNLO.sect11.dat → NNLO.sect11.final.dat
# ✅ Renamed: NNLO.sect11.pdf.dat → NNLO.sect11.pdf.final.dat
# ✅ Renamed: NNLO.sect12.dat → NNLO.sect12.final.dat
# ✅ Renamed: NNLO.sect12.pdf.dat → NNLO.sect12.pdf.final.dat
# ✅ Renamed: NNLO.sect13.dat → NNLO.sect13.final.dat
# ✅ Renamed: NNLO.sect13.pdf.dat → NNLO.sect13.pdf.final.dat
# ✅ Renamed: NNLO.sect14.dat → NNLO.sect14.final.dat
# ✅ Renamed: NNLO.sect14.pdf.dat → NNLO.sect14.pdf.final.dat
# ✅ Renamed: NNLO.sect15.dat → NNLO.sect15.final.dat
# ✅ Renamed: NNLO.sect15.pdf.dat → NNLO.sect15.pdf.final.dat
# ✅ Renamed: NNLO.sect16.dat → NNLO.sect16.final.dat
# ✅ Renamed: NNLO.sect16.pdf.dat → NNLO.sect16.pdf.final.dat
# ✅ Renamed: NNLO.sect17.dat → NNLO.sect17.final.dat
# ✅ Renamed: NNLO.sect17.pdf.dat → NNLO.sect17.pdf.final.dat
# ✅ Renamed: NNLO.sect18.dat → NNLO.sect18.final.dat
# ✅ Renamed: NNLO.sect18.pdf.dat → NNLO.sect18.pdf.final.dat
# ✅ Renamed: NNLO.sect19.dat → NNLO.sect19.final.dat
# ✅ Renamed: NNLO.sect19.pdf.dat → NNLO.sect19.pdf.final.dat
# ✅ Renamed: NNLO.sect20.dat → NNLO.sect20.final.dat
# ✅ Renamed: NNLO.sect20.pdf.dat → NNLO.sect20.pdf.final.dat
# ✅ Renamed: NNLO.sect21.dat → NNLO.sect21.final.dat
# ✅ Renamed: NNLO.sect21.pdf.dat → NNLO.sect21.pdf.final.dat
# ✅ Renamed: NNLO.sect22.dat → NNLO.sect22.final.dat
# ✅ Renamed: NNLO.sect22.pdf.dat → NNLO.sect22.pdf.final.dat
# ✅ Renamed: NNLO.sect23.dat → NNLO.sect23.final.dat
# ✅ Renamed: NNLO.sect23.pdf.dat → NNLO.sect23.pdf.final.dat
# ✅ Renamed: NNLO.sect24.dat → NNLO.sect24.final.dat
# ✅ Renamed: NNLO.sect24.pdf.dat → NNLO.sect24.pdf.final.dat
# ✅ Renamed: NNLO.sect25.dat → NNLO.sect25.final.dat
# ✅ Renamed: NNLO.sect25.pdf.dat → NNLO.sect25.pdf.final.dat
# ✅ Renamed: NNLO.sect26.dat → NNLO.sect26.final.dat
# ✅ Renamed: NNLO.sect26.pdf.dat → NNLO.sect26.pdf.final.dat
# ✅ Renamed: NNLO.sect27.pdf.dat → NNLO.sect27.pdf.final.dat
# ✅ Renamed: NNLO.sect27.dat → NNLO.sect27.final.dat
# ✅ Renamed: NNLO.sect28.dat → NNLO.sect28.final.dat
# ✅ Renamed: NNLO.sect28.pdf.dat → NNLO.sect28.pdf.final.dat
# ✅ Renamed: NNLO.sect29.dat → NNLO.sect29.final.dat
# ✅ Renamed: NNLO.sect29.pdf.dat → NNLO.sect29.pdf.final.dat
# ✅ Renamed: NNLO.sect30.pdf.dat → NNLO.sect30.pdf.final.dat
# ✅ Renamed: NNLO.sect30.dat → NNLO.sect30.final.dat
# ✅ Renamed: NNLO.sect31.dat → NNLO.sect31.final.dat
# ✅ Renamed: NNLO.sect31.pdf.dat → NNLO.sect31.pdf.final.dat
# ✅ Renamed: NNLO.sect32.dat → NNLO.sect32.final.dat
# ✅ Renamed: NNLO.sect32.pdf.dat → NNLO.sect32.pdf.final.dat
# ✅ Renamed: NNLO.sect33.pdf.dat → NNLO.sect33.pdf.final.dat
# ✅ Renamed: NNLO.sect33.dat → NNLO.sect33.final.dat
# ✅ Renamed: NNLO.sect34.dat → NNLO.sect34.final.dat
# ✅ Renamed: NNLO.sect34.pdf.dat → NNLO.sect34.pdf.final.dat
# ✅ Renamed: NNLO.sect35.dat → NNLO.sect35.final.dat
# ✅ Renamed: NNLO.sect35.pdf.dat → NNLO.sect35.pdf.final.dat
# ✅ Renamed: NNLO.sect36.dat → NNLO.sect36.final.dat
# ✅ Renamed: NNLO.sect36.pdf.dat → NNLO.sect36.pdf.final.dat
# ✅ Renamed: NNLO.sect37.dat → NNLO.sect37.final.dat
# ✅ Renamed: NNLO.sect37.pdf.dat → NNLO.sect37.pdf.final.dat
# ✅ Renamed: NNLO.sect38.dat → NNLO.sect38.final.dat
# ✅ Renamed: NNLO.sect38.pdf.dat → NNLO.sect38.pdf.final.dat
# ✅ Renamed: NNLO.sect39.dat → NNLO.sect39.final.dat
# ✅ Renamed: NNLO.sect39.pdf.dat → NNLO.sect39.pdf.final.dat
# ✅ Renamed: NNLO.sect40.dat → NNLO.sect40.final.dat
# ✅ Renamed: NNLO.sect40.pdf.dat → NNLO.sect40.pdf.final.dat
# ✅ Renamed: NNLO.sect41.dat → NNLO.sect41.final.dat
# ✅ Renamed: NNLO.sect41.pdf.dat → NNLO.sect41.pdf.final.dat
# ✅ Renamed: NNLO.sect42.dat → NNLO.sect42.final.dat
# ✅ Renamed: NNLO.sect42.pdf.dat → NNLO.sect42.pdf.final.dat
# ✅ Renamed: NNLO.sect43.dat → NNLO.sect43.final.dat
# ✅ Renamed: NNLO.sect43.pdf.dat → NNLO.sect43.pdf.final.dat
# ✅ Renamed: NNLO.sect44.dat → NNLO.sect44.final.dat
# ✅ Renamed: NNLO.sect44.pdf.dat → NNLO.sect44.pdf.final.dat
# ✅ Renamed: NNLO.sect45.dat → NNLO.sect45.final.dat
# ✅ Renamed: NNLO.sect45.pdf.dat → NNLO.sect45.pdf.final.dat
# ✅ Renamed: NNLO.sect46.dat → NNLO.sect46.final.dat
# ✅ Renamed: NNLO.sect46.pdf.dat → NNLO.sect46.pdf.final.dat
# ✅ Renamed: NNLO.sect47.dat → NNLO.sect47.final.dat
# ✅ Renamed: NNLO.sect47.pdf.dat → NNLO.sect47.pdf.final.dat
# ✅ Renamed: NNLO.sect48.dat → NNLO.sect48.final.dat
# ✅ Renamed: NNLO.sect48.pdf.dat → NNLO.sect48.pdf.final.dat
# ✅ Renamed: NNLO.sect49.dat → NNLO.sect49.final.dat
# ✅ Renamed: NNLO.sect49.pdf.dat → NNLO.sect49.pdf.final.dat
# ✅ Renamed: NNLO.sect50.dat → NNLO.sect50.final.dat
# ✅ Renamed: NNLO.sect50.pdf.dat → NNLO.sect50.pdf.final.dat
# ✅ Renamed: NNLO.sect51.dat → NNLO.sect51.final.dat
# ✅ Renamed: NNLO.sect51.pdf.dat → NNLO.sect51.pdf.final.dat
# ✅ Renamed: NNLO.sect52.pdf.dat → NNLO.sect52.pdf.final.dat
# ✅ Renamed: NNLO.sect52.dat → NNLO.sect52.final.dat
# ✅ Renamed: NNLO.sect53.dat → NNLO.sect53.final.dat
# ✅ Renamed: NNLO.sect53.pdf.dat → NNLO.sect53.pdf.final.dat
# ✅ Renamed: NNLO.sect54.pdf.dat → NNLO.sect54.pdf.final.dat
# ✅ Renamed: NNLO.sect54.dat → NNLO.sect54.final.dat
# ✅ Renamed: NNLO.sect55.dat → NNLO.sect55.final.dat
# ✅ Renamed: NNLO.sect55.pdf.dat → NNLO.sect55.pdf.final.dat
# ✅ Renamed: NNLO.sect56.pdf.dat → NNLO.sect56.pdf.final.dat
# ✅ Renamed: NNLO.sect56.dat → NNLO.sect56.final.dat
# ✅ Renamed: NNLO.sect57.dat → NNLO.sect57.final.dat
# ✅ Renamed: NNLO.sect57.pdf.dat → NNLO.sect57.pdf.final.dat
# ✅ Renamed: NNLO.sect58.dat → NNLO.sect58.final.dat
# ✅ Renamed: NNLO.sect58.pdf.dat → NNLO.sect58.pdf.final.dat
# ✅ Renamed: NNLO.sect59.dat → NNLO.sect59.final.dat
# ✅ Renamed: NNLO.sect59.pdf.dat → NNLO.sect59.pdf.final.dat
# ✅ Renamed: NNLO.sect60.dat → NNLO.sect60.final.dat
# ✅ Renamed: NNLO.sect60.pdf.dat → NNLO.sect60.pdf.final.dat
# ✅ Renamed: NNLO.sect61.dat → NNLO.sect61.final.dat
# ✅ Renamed: NNLO.sect61.pdf.dat → NNLO.sect61.pdf.final.dat
# ✅ Renamed: NNLO.sect62.dat → NNLO.sect62.final.dat
# ✅ Renamed: NNLO.sect62.pdf.dat → NNLO.sect62.pdf.final.dat
# ✅ Renamed: NNLO.sect63.dat → NNLO.sect63.final.dat
# ✅ Renamed: NNLO.sect63.pdf.dat → NNLO.sect63.pdf.final.dat
# ✅ Renamed: NNLO.sect64.dat → NNLO.sect64.final.dat
# ✅ Renamed: NNLO.sect64.pdf.dat → NNLO.sect64.pdf.final.dat
# ✅ Renamed: NNLO.sect65.pdf.dat → NNLO.sect65.pdf.final.dat
# ✅ Renamed: NNLO.sect65.dat → NNLO.sect65.final.dat
# ✅ Renamed: NNLO.sect66.dat → NNLO.sect66.final.dat
# ✅ Renamed: NNLO.sect66.pdf.dat → NNLO.sect66.pdf.final.dat
# ✅ Renamed: NNLO.sect67.pdf.dat → NNLO.sect67.pdf.final.dat
# ✅ Renamed: NNLO.sect67.dat → NNLO.sect67.final.dat
# ✅ Renamed: NNLO.sect68.dat → NNLO.sect68.final.dat
# ✅ Renamed: NNLO.sect68.pdf.dat → NNLO.sect68.pdf.final.dat
# ✅ Renamed: NNLO.sect69.pdf.dat → NNLO.sect69.pdf.final.dat
# ✅ Renamed: NNLO.sect69.dat → NNLO.sect69.final.dat
# ✅ Renamed: NNLO.sect70.pdf.dat → NNLO.sect70.pdf.final.dat
# ✅ Renamed: NNLO.sect70.dat → NNLO.sect70.final.dat
# ✅ Renamed: NNLO.sect71.dat → NNLO.sect71.final.dat
# ✅ Renamed: NNLO.sect71.pdf.dat → NNLO.sect71.pdf.final.dat
# ✅ Renamed: NNLO.sect72.dat → NNLO.sect72.final.dat
# ✅ Renamed: NNLO.sect72.pdf.dat → NNLO.sect72.pdf.final.dat
# ✅ Renamed: NNLO.sect73.dat → NNLO.sect73.final.dat
# ✅ Renamed: NNLO.sect73.pdf.dat → NNLO.sect73.pdf.final.dat
# ✅ Renamed: NNLO.sect74.pdf.dat → NNLO.sect74.pdf.final.dat
# ✅ Renamed: NNLO.sect74.dat → NNLO.sect74.final.dat
# ✅ Renamed: NNLO.sect75.dat → NNLO.sect75.final.dat
# ✅ Renamed: NNLO.sect75.pdf.dat → NNLO.sect75.pdf.final.dat
# ✅ Renamed: NNLO.sect76.dat → NNLO.sect76.final.dat
# ✅ Renamed: NNLO.sect76.pdf.dat → NNLO.sect76.pdf.final.dat
# ✅ Renamed: NNLO.sect77.dat → NNLO.sect77.final.dat
# ✅ Renamed: NNLO.sect77.pdf.dat → NNLO.sect77.pdf.final.dat
# ✅ Renamed: NNLO.sect78.dat → NNLO.sect78.final.dat
# ✅ Renamed: NNLO.sect78.pdf.dat → NNLO.sect78.pdf.final.dat
# ✅ Renamed: NNLO.sect79.dat → NNLO.sect79.final.dat
# ✅ Renamed: NNLO.sect79.pdf.dat → NNLO.sect79.pdf.final.dat
# ✅ Renamed: NNLO.sect80.dat → NNLO.sect80.final.dat
# ✅ Renamed: NNLO.sect80.pdf.dat → NNLO.sect80.pdf.final.dat
# ✅ Renamed: NNLO.sect81.dat → NNLO.sect81.final.dat
# ✅ Renamed: NNLO.sect81.pdf.dat → NNLO.sect81.pdf.final.dat
# ✅ Renamed: NNLO.sect82.dat → NNLO.sect82.final.dat
# ✅ Renamed: NNLO.sect82.pdf.dat → NNLO.sect82.pdf.final.dat
# ✅ Renamed: NNLO.sect83.dat → NNLO.sect83.final.dat
# ✅ Renamed: NNLO.sect83.pdf.dat → NNLO.sect83.pdf.final.dat
# ✅ Renamed: NNLO.sect84.dat → NNLO.sect84.final.dat
# ✅ Renamed: NNLO.sect84.pdf.dat → NNLO.sect84.pdf.final.dat
# ✅ Renamed: NNLO.sect85.dat → NNLO.sect85.final.dat
# ✅ Renamed: NNLO.sect85.pdf.dat → NNLO.sect85.pdf.final.dat
# ✅ Renamed: NNLO.sect86.dat → NNLO.sect86.final.dat
# ✅ Renamed: NNLO.sect86.pdf.dat → NNLO.sect86.pdf.final.dat
# ✅ Renamed: NNLO.sect87.pdf.dat → NNLO.sect87.pdf.final.dat
# ✅ Renamed: NNLO.sect87.dat → NNLO.sect87.final.dat
# ✅ Renamed: NNLO.sect88.pdf.dat → NNLO.sect88.pdf.final.dat
# ✅ Renamed: NNLO.sect88.dat → NNLO.sect88.final.dat
# ✅ Renamed: NNLO.sect89.dat → NNLO.sect89.final.dat
# ✅ Renamed: NNLO.sect89.pdf.dat → NNLO.sect89.pdf.final.dat
# ✅ Renamed: NNLO.sect90.pdf.dat → NNLO.sect90.pdf.final.dat
# ✅ Renamed: NNLO.sect90.dat → NNLO.sect90.final.dat
# ✅ Renamed: NNLO.sect91.dat → NNLO.sect91.final.dat
# ✅ Renamed: NNLO.sect91.pdf.dat → NNLO.sect91.pdf.final.dat
# ✅ Renamed: NNLO.sect92.dat → NNLO.sect92.final.dat
# ✅ Renamed: NNLO.sect92.pdf.dat → NNLO.sect92.pdf.final.dat
# ✅ Renamed: NNLO.sect93.dat → NNLO.sect93.final.dat
# ✅ Renamed: NNLO.sect93.pdf.dat → NNLO.sect93.pdf.final.dat
# ✅ Renamed: NNLO.sect94.dat → NNLO.sect94.final.dat
# ✅ Renamed: NNLO.sect94.pdf.dat → NNLO.sect94.pdf.final.dat
# ✅ Renamed: NNLO.sect95.dat → NNLO.sect95.final.dat
# ✅ Renamed: NNLO.sect95.pdf.dat → NNLO.sect95.pdf.final.dat
# ✅ Renamed: NNLO.sect96.pdf.dat → NNLO.sect96.pdf.final.dat
# ✅ Renamed: NNLO.sect96.dat → NNLO.sect96.final.dat
# ✅ Renamed: NNLO.sect97.dat → NNLO.sect97.final.dat
# ✅ Renamed: NNLO.sect97.pdf.dat → NNLO.sect97.pdf.final.dat
# ✅ Renamed: NNLO.sect98.dat → NNLO.sect98.final.dat
# ✅ Renamed: NNLO.sect98.pdf.dat → NNLO.sect98.pdf.final.dat
# ✅ Renamed: NNLO.sect99.dat → NNLO.sect99.final.dat
# ✅ Renamed: NNLO.sect99.pdf.dat → NNLO.sect99.pdf.final.dat
# ✅ Renamed: NNLO.sect100.dat → NNLO.sect100.final.dat
# ✅ Renamed: NNLO.sect100.pdf.dat → NNLO.sect100.pdf.final.dat
# ✅ Renamed: NNLO.sect101.pdf.dat → NNLO.sect101.pdf.final.dat
# ✅ Renamed: NNLO.sect101.dat → NNLO.sect101.final.dat
# ✅ Renamed: NNLO.sect102.dat → NNLO.sect102.final.dat
# ✅ Renamed: NNLO.sect102.pdf.dat → NNLO.sect102.pdf.final.dat
# ✅ Renamed: NNLO.sect103.dat → NNLO.sect103.final.dat
# ✅ Renamed: NNLO.sect103.pdf.dat → NNLO.sect103.pdf.final.dat
# ✅ Renamed: NNLO.sect104.dat → NNLO.sect104.final.dat
# ✅ Renamed: NNLO.sect104.pdf.dat → NNLO.sect104.pdf.final.dat
# ✅ Renamed: NNLO.sect105.dat → NNLO.sect105.final.dat
# ✅ Renamed: NNLO.sect105.pdf.dat → NNLO.sect105.pdf.final.dat
# ✅ Renamed: NNLO.sect106.pdf.dat → NNLO.sect106.pdf.final.dat
# ✅ Renamed: NNLO.sect106.dat → NNLO.sect106.final.dat
# ✅ Renamed: NNLO.sect107.dat → NNLO.sect107.final.dat
# ✅ Renamed: NNLO.sect107.pdf.dat → NNLO.sect107.pdf.final.dat
# ✅ Renamed: NNLO.sect108.dat → NNLO.sect108.final.dat
# ✅ Renamed: NNLO.sect108.pdf.dat → NNLO.sect108.pdf.final.dat
# ✅ Renamed: NNLO.sect109.dat → NNLO.sect109.final.dat
# ✅ Renamed: NNLO.sect109.pdf.dat → NNLO.sect109.pdf.final.dat
# ✅ Renamed: NNLO.sect110.pdf.dat → NNLO.sect110.pdf.final.dat
# ✅ Renamed: NNLO.sect110.dat → NNLO.sect110.final.dat
# ✅ Renamed: NNLO.sect111.dat → NNLO.sect111.final.dat
# ✅ Renamed: NNLO.sect111.pdf.dat → NNLO.sect111.pdf.final.dat
# ✅ Renamed: NNLO.sect112.dat → NNLO.sect112.final.dat
# ✅ Renamed: NNLO.sect112.pdf.dat → NNLO.sect112.pdf.final.dat
# ✅ Renamed: NNLO.sect113.dat → NNLO.sect113.final.dat
# ✅ Renamed: NNLO.sect113.pdf.dat → NNLO.sect113.pdf.final.dat
# ✅ Renamed: NNLO.sect114.pdf.dat → NNLO.sect114.pdf.final.dat
# ✅ Renamed: NNLO.sect114.dat → NNLO.sect114.final.dat
# ✅ Renamed: NNLO.sect115.dat → NNLO.sect115.final.dat
# ✅ Renamed: NNLO.sect115.pdf.dat → NNLO.sect115.pdf.final.dat
# ✅ Renamed: NNLO.sect116.dat → NNLO.sect116.final.dat
# ✅ Renamed: NNLO.sect116.pdf.dat → NNLO.sect116.pdf.final.dat
# ✅ Renamed: NNLO.sect117.pdf.dat → NNLO.sect117.pdf.final.dat
# ✅ Renamed: NNLO.sect117.dat → NNLO.sect117.final.dat
# ✅ Renamed: NNLO.sect118.dat → NNLO.sect118.final.dat
# ✅ Renamed: NNLO.sect118.pdf.dat → NNLO.sect118.pdf.final.dat
# ✅ Renamed: NNLO.sect119.dat → NNLO.sect119.final.dat
# ✅ Renamed: NNLO.sect119.pdf.dat → NNLO.sect119.pdf.final.dat
# ✅ Renamed: NNLO.sect120.dat → NNLO.sect120.final.dat
# ✅ Renamed: NNLO.sect120.pdf.dat → NNLO.sect120.pdf.final.dat
# ✅ Renamed: NNLO.sect121.dat → NNLO.sect121.final.dat
# ✅ Renamed: NNLO.sect121.pdf.dat → NNLO.sect121.pdf.final.dat
# ✅ Renamed: NNLO.sect122.dat → NNLO.sect122.final.dat
# ✅ Renamed: NNLO.sect122.pdf.dat → NNLO.sect122.pdf.final.dat
# ✅ Renamed: NNLO.sect123.dat → NNLO.sect123.final.dat
# ✅ Renamed: NNLO.sect123.pdf.dat → NNLO.sect123.pdf.final.dat
# ✅ Renamed: NNLO.sect124.dat → NNLO.sect124.final.dat
# ✅ Renamed: NNLO.sect124.pdf.dat → NNLO.sect124.pdf.final.dat
# ✅ Renamed: NNLO.sect125.dat → NNLO.sect125.final.dat
# ✅ Renamed: NNLO.sect125.pdf.dat → NNLO.sect125.pdf.final.dat
# ✅ Renamed: NNLO.sect126.dat → NNLO.sect126.final.dat
# ✅ Renamed: NNLO.sect126.pdf.dat → NNLO.sect126.pdf.final.dat
# ✅ Renamed: NNLO.sect127.dat → NNLO.sect127.final.dat
# ✅ Renamed: NNLO.sect127.pdf.dat → NNLO.sect127.pdf.final.dat
#
# 🎉 모든 이름 변경 완료.
